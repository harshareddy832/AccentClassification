# %%
# !pip install pydub
# !pip install pickle5
# Out:
# Collecting pydub
#   Downloading pydub-0.25.1-py2.py3-none-any.whl (32 kB)
# Installing collected packages: pydub
# Successfully installed pydub-0.25.1
# Collecting pickle5
#   Downloading pickle5-0.0.11.tar.gz (132 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.1/132.1 kB 3.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: pickle5
#   Building wheel for pickle5 (setup.py) ... done
#   Created wheel for pickle5: filename=pickle5-0.0.11-cp310-cp310-linux_x86_64.whl size=255317 sha256=8e898acc3632ea779c62f77755120493e1bb81f11795e0ae008568b9fbed04bf
#   Stored in directory: /root/.cache/pip/wheels/7d/14/ef/4aab19d27fa8e58772be5c71c16add0426acf9e1f64353235c
# Successfully built pickle5
# Installing collected packages: pickle5
# Successfully installed pickle5-0.0.11

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import librosa
import librosa.display
import json
from tqdm import tqdm
import os
import tensorflow as tf


import IPython.display
import sklearn.preprocessing
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Activation, Dense, Dropout, Flatten, Conv2D, MaxPooling2D
from tensorflow.keras.callbacks import TensorBoard
from tensorflow.keras.metrics import binary_crossentropy
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import  f1_score
from tensorflow.keras.callbacks import Callback
import tensorflow.keras.backend as K
import librosa
from tensorflow import keras
from keras.callbacks import Callback
from keras.callbacks import TensorBoard
import pydub
import pickle5 as pickle
import librosa.display
import os

# %%
try:
    from google.colab import drive
    drive.mount('/content/drive')
except Exception as e:
    print(f"Error mounting Google Drive: {e}")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Path to the directory containing MP3 recordings
mp3_path = '/content/drive/MyDrive/DataAML/recordings/recordings/'

# %%
import os

if os.path.exists(mp3_path):
    files = os.listdir(mp3_path)
    print(files)
else:
    print(f"Path not found: {mp3_path}")
# Out:
# ['hebrew7.mp3', 'hebrew4.mp3', 'hindi12.mp3', 'hungarian1.mp3', 'hmong1.mp3', 'hmong2.mp3', 'hebrew3.mp3', 'hindi9.mp3', 'hausa8.mp3', 'hungarian9.mp3', 'hausa5.mp3', 'hausa3.mp3', 'hindi11.mp3', 'hungarian3.mp3', 'hausa7.mp3', 'indonesian6.mp3', 'italian1.mp3', 'italian12.mp3', 'ilonggo1.mp3', 'icelandic3.mp3', 'italian17.mp3', 'italian18.mp3', 'indonesian4.mp3', 'italian32.mp3', 'igbo2.mp3', 'italian19.mp3', 'italian10.mp3', 'italian23.mp3', 'ife1.mp3', 'indonesian5.mp3', 'italian3.mp3', 'indonesian2.mp3', 'italian25.mp3', 'italian2.mp3', 'italian26.mp3', 'icelandic2.mp3', 'italian22.mp3', 'indonesian3.mp3', 'igbo3.mp3', 'italian27.mp3', 'italian6.mp3', 'italian5.mp3', 'italian13.mp3', 'italian16.mp3', 'italian14.mp3', 'italian24.mp3', 'italian15.mp3', 'ibibio2.mp3', 'ibibio1.mp3', 'indonesian1.mp3', 'italian28.mp3', 'italian11.mp3', 'italian21.mp3', 'indonesian8.mp3', 'italian30.mp3', 'indonesian7.mp3', 'italian4.mp3', 'italian20.mp3', 'icelandic1.mp3', 'italian31.mp3', 'igbo1.mp3', 'irish1.mp3', 'ibibio3.mp3', 'italian29.mp3', 'italian33.mp3', 'japanese10.mp3', 'kambaata2.mp3', 'japanese25.mp3', 'japanese24.mp3', 'japanese6.mp3', 'japanese12.mp3', 'japanese26.mp3', 'jola1.mp3', 'kabyle1.mp3', 'japanese4.mp3', 'khmer3.mp3', 'japanese8.mp3', 'japanese27.mp3', 'italian7.mp3', 'khmer1.
 'macedonian1.mp3', 'macedonian5.mp3', 'macedonian7.mp3', 'macedonian20.mp3', 'macedonian23.mp3', 'macedonian4.mp3', 'macedonian8.mp3', 'luo1.mp3', 'luxembourgeois1.mp3', 'lithuanian3.mp3', 'macedonian25.mp3', 'macedonian14.mp3', 'macedonian2.mp3', 'macedonian18.mp3', 'macedonian21.mp3', 'lithuanian4.mp3', 'lao3.mp3', 'latvian2.mp3', 'lamotrekese1.mp3', 'kurdis ...

# %%
try:
    mp3_filenames = os.listdir(mp3_path)
    print(f"Number of files found: {len(mp3_filenames)}")
except FileNotFoundError:
    print(f"Directory not found: {mp3_path}")
# Out:
# Number of files found: 2138

# %%
from pydub import AudioSegment

if mp3_filenames:
    example_file = mp3_filenames[0]
    audio = AudioSegment.from_mp3(mp3_path + example_file)
    print(f"Loaded file: {example_file}")
else:
    print("No MP3 files found in the directory.")
# Out:
# Loaded file: hebrew7.mp3

# %%
wav_path = '/content/drive/MyDrive/DataAML/recordings/wav/'

try:
    wav_filenames = os.listdir(wav_path)
    if wav_filenames:
        example_wave_filename = wav_filenames[0]
        example_wave, example_sr = librosa.load(wav_path + example_wave_filename, mono=True)
        print(f"Loaded WAV file: {example_wave_filename}")
    else:
        print("No WAV files found in the directory.")
except FileNotFoundError:
    print(f"Directory not found: {wav_path}")
# Out:
# Loaded WAV file: dutch3.wav

# %%
from tqdm.auto import tqdm

file_name_mfcc = []
for filename in tqdm(wav_filenames, desc="Extracting MFCC"):
    try:
        wave, sr = librosa.load(wav_path + filename, mono=True)
        mfcc = librosa.feature.mfcc(y=wave, sr=sr)
        file_name_mfcc.append([filename, wave, mfcc, sr])
    except Exception as e:
        print(f"Error processing {filename}: {e}")
# Out:
# Extracting MFCC:   0%|          | 0/2138 [00:00<?, ?it/s]

# %%
file_name_mfcc_df = pd.DataFrame(file_name_mfcc, columns=['Filename', 'Wave', 'MFCC', 'SampleRate'])
print(file_name_mfcc_df.head())
# Out:
#       Filename                                               Wave  \
# 0   dutch3.wav  [-1.2286007e-05, -8.648785e-06, -1.2129894e-06...
# 1  dutch47.wav  [0.00027062165, 0.0004607554, 0.00074456714, 0...
# 2  dutch23.wav  [0.002694809, 0.00406893, 0.003953251, 0.00417...
# 3  dutch15.wav  [2.0103284e-05, -8.6206273e-07, 7.642557e-06, ...
# 4  dutch13.wav  [0.0021557808, 0.0035218182, 0.0029537925, 0.0...
#
#                                                 MFCC  SampleRate
# 0  [[-486.25443, -374.78333, -348.9275, -346.9744...       22050
# 1  [[-516.39923, -508.06088, -511.3895, -514.771,...       22050
# 2  [[-548.496, -574.7447, -596.69055, -596.6928, ...       22050
# 3  [[-611.2188, -611.2188, -611.2188, -611.2188, ...       22050
# 4  [[-473.73676, -461.5163, -469.26108, -465.6553...       22050

# %%
# Creating a smaller DataFrame with specific columns
if 'file_name' in file_name_mfcc_df.columns and 'mfcc' in file_name_mfcc_df.columns:
    small_df = file_name_mfcc_df[['file_name', 'mfcc', 'sr']]
else:
    print("Required columns not found in the DataFrame.")
# Out:
# Required columns not found in the DataFrame.

# %%
if not small_df.empty and 'mfcc' in small_df.columns:
    plt.figure(figsize=(10, 4))
    librosa.display.specshow(small_df['mfcc'][0], x_axis='time', sr=small_df['sr'][0])
    plt.colorbar(format='%+2.0f dB')
    plt.title('MFCC')
    plt.tight_layout()
    plt.show()
else:
    print("MFCC data not available for visualization.")

# %%
if 'file_name' in small_df.columns:
    small_df['native_language'] = small_df['file_name'].str.extract(r'([^\d]+)', expand=False)
else:
    print("File names not available for label extraction.")

# %%
small_df['native_language'] = small_df.apply(lambda x: ''.join([i for i in x['native_language'] if not i.isdigit()]), axis=1)

# %%
small_df['flag']=np.where(small_df['native_language']=='english',1,0)
small_df[small_df['native_language']=='english'].iloc[:30]
# Out:
#          file_name                                               mfcc     sr  \
# 50  english133.wav  [[-438.1929, -420.52206, -421.09845, -423.3392...  22050
# 51  english122.wav  [[-579.7075, -575.2393, -575.9098, -576.16833,...  22050
# 52  english134.wav  [[-428.71567, -425.77945, -446.1692, -445.9987...  22050
# 53  english103.wav  [[-461.3125, -467.71704, -474.062, -475.93628,...  22050
# 54  english127.wav  [[-553.33575, -540.83264, -544.7995, -544.0653...  22050
# 55  english111.wav  [[-529.31384, -529.31384, -529.31384, -529.313...  22050
# 56  english120.wav  [[-514.93256, -502.24823, -504.01514, -507.324...  22050
# 57  english106.wav  [[-562.2517, -562.2517, -562.2517, -562.2517, ...  22050
# 58  english112.wav  [[-523.782, -521.95715, -520.9799, -521.9167, ...  22050
# 59  english146.wav  [[-500.4557, -508.70013, -535.2393, -539.4193,...  22050
# 60  english117.wav  [[-521.62634, -521.62634, -521.62634, -521.626...  22050
# 61  english136.wav  [[-518.85126, -523.8828, -545.4999, -552.8495,...  22050
# 62  english132.wav  [[-375.22498, -340.68594, -341.28995, -338.660...  22050
# 63  english143.wav  [[-386.93436, -350.51483, -344.02884, -346.222...  22050
# 64  english145.wav  [[-286.54004, -322.73163, -376.6527, -382.3887...  22050
# 65  english121.wav  [[-413.96017, -378.05896, -376.64337, -381.997...  22050
# 66  english110.wav  [[-563.9938, -563.9728, -564.0191, -564.0019, ...  22050
# 67  english100.wav  [[-551.81305, -552.03424, -552.09576, -552.087...  22050
# 68  english138.wav  [[-613.2234, -613.2234, -613.2234, -613.2234, ...  22050
# 69  english128.wav  [[-501.85678, -484.8843, -493.35733, -492.2396...  22050
# 70  english135.wav  [[-484.10046, -463.65372, -460.94727, -432.243...  22050
# 71  english126.wav  [[-433.31296, -389.71777, -379.16153, -391.990...  22050
# 72  english140.wav  [[-544.44104, -524.8509, -524.7269, -523.86926...  22050
# 73  english137.wav  [[-602.1133, -602.1133, -602.1133, -602.1133, ...  22050
# 74  english114.wav  [[-491.54922, -462.20734, -452.09613, -442.349...  22050
# 76  english125.wav  [[-412.99847, -392.19772, -395.36954, -392.999...  22050
# 78  english139.wav  [[-490.03207, -471.9587, -485.6463, -494.76157...  22050
# 79  english129.wav  [[-408.24985, -377.17715, -385.92285, -394.399...  22050
# 80  english108.wav  [[-484.6188, -484.6188, -484.6188, -484.6188, ...  22050
# 81  english101.wav  [[-549.53674, -537.9779, -529.9125, -525.55505...  22050
#
#    native_language  flag                                        padded_mfcc
# 50         english     1  [[-438.1929, -420.52206, -421.09845, -423.3392...
# 51         english     1  [[-579.7075, -575.2393, -575.9098, -576.16833,...
# 52         english     1  [[-428.71567, -425.77945, -446.1692, -445.9987...
# 53         english     1  [[-461.3125, -467.71704, -474.062, -475.93628,...
# 54         english     1  [[-553.33575, -540.83264, -544.7995, -544.0653...
# 55         english     1  [[-529.31384, -529.31384, -529.31384, -529.313...
# 56         english     1  [[-514.93256, -502.24823, -504.01514, -507.324...
# 57         english     1  [[-562.2517, -562.2517, -562.2517, -562.2517, ...
# 58         english     1  [[-523.782, -521.95715, -520.9799, -521.9167, ...
# 59         english     1  [[-500.4557, -508.70013, -535.2393, -539.4193,...
# 60         english     1  [[-521.62634, -521.62634, -521.62634, -521.626...
# 61         english     1  [[-518.85126, -523.8828, -545.4999, -552.8495,...
# 62         english     1  [[-375.22498, -340.68594, -341.28995, -338.660...
# 63         english     1  [[-386.93436, -350.51483, -344.02884, -346.222...
# 64         english     1  [[-286.54004, -322.73163, -376.6527, -382.3887...
# 65         english     1  [[-413.96017, -378.05896, -376.64337, -381.997...
# 66         english     1  [[-563.9938, -563.9728, -564.0191, -564.0019, ...
# 67         english     1  [[-551.81305, -552.03424, -552.09576, -552.087...
# 68         english     1  [[-613.2234, -613.2234, -613.2234, -613.2234, ...
# 69         english     1  [[-501.85678, -484.8843, -493.35733, -492.2396...
# 70         english     1  [[-484.10046, -463.65372, -460.94727, -432.243...
# 71         english     1  [[-433.31296, -389.71777, -379.16153, -391.990...
# 72         english     1  [[-544.44104, -524.8509, -524.7269, -523.86926...
# 73         english     1  [[-602.1133, -602.1133, -602.1133, -602.1133, ...
# 74         english     1  [[-491.54922, -462.20734, -452.09613, -442.349...
# 76         english     1  [[-412.99847, -392.19772, -395.36954, -392.999...
# 78         english     1  [[-490.03207, -471.9587, -485.6463, -494.76157...
# 79         english     1  [[-408.24985, -377.17715, -385.92285, -394.399...
# 80         english     1  [[-484.6188, -484.6188, -484.6188, -484.6188, ...
# 81         english     1  [[-549.53674, -537.9779, -529.9125, -525.55505...

# %%
if 'mfcc' in small_df.columns and not small_df['mfcc'].empty:
    MFCC_MAX_LEN = max(arr.shape[1] for arr in small_df['mfcc'])
    print(f"Maximum MFCC Length: {MFCC_MAX_LEN}")
else:
    print("MFCC column not found or empty.")
# Out:
# Maximum MFCC Length: 4589

# %%
if 'mfcc' in small_df.columns and not small_df['mfcc'].empty:
    MFCC_NUM = max(arr.shape[0] for arr in small_df['mfcc'])
    print(f"Number of MFCC Coefficients: {MFCC_NUM}")
else:
    print("MFCC column not found or empty.")
# Out:
# Number of MFCC Coefficients: 20

# %%
def resize_mfcc(df, max_len):
    if 'mfcc' in df.columns:
        df['padded_mfcc'] = df['mfcc'].apply(lambda x: librosa.util.fix_length(data=x, size=max_len, axis=1))
        return df
    else:
        print("MFCC column not found in the DataFrame.")
        return df

if 'MFCC_MAX_LEN' in locals():
    df = resize_mfcc(small_df, MFCC_MAX_LEN)
else:
    print("MFCC_MAX_LEN not defined.")

# %%
from sklearn.model_selection import train_test_split

if not df.empty:
    train_df, rest_df = train_test_split(df, test_size=0.6, random_state=123)
    val_df, test_df = train_test_split(rest_df, test_size=0.5, random_state=123)
else:
    print("DataFrame is empty. Cannot split data.")

# %%
if not train_df.empty and 'padded_mfcc' in train_df.columns:
    x_train = np.array(list(train_df['padded_mfcc']))
else:
    print("Training data is not available or incomplete.")

if not val_df.empty and 'padded_mfcc' in val_df.columns:
    x_val = np.array(list(val_df['padded_mfcc']))
else:
    print("Validation data is not available or incomplete.")

if not test_df.empty and 'padded_mfcc' in test_df.columns:
    x_test = np.array(list(test_df['padded_mfcc']))
else:
    print("Test data is not available or incomplete.")

# %%
label_column = 'flag'  # Replace with the actual label column name if different

if label_column in train_df.columns:
    y_train = train_df[label_column].values
else:
    print("Label column not found in training data.")

if label_column in val_df.columns:
    y_val = val_df[label_column].values
else:
    print("Label column not found in validation data.")

if label_column in test_df.columns:
    y_test = test_df[label_column].values
else:
    print("Label column not found in test data.")

# %%
feature_dim_1 = MFCC_NUM
feature_dim_2 = MFCC_MAX_LEN
channel = 1

# %%
x_train_reshaped = x_train.reshape(x_train.shape[0], feature_dim_1, feature_dim_2, channel)
x_val_reshaped = x_val.reshape(x_val.shape[0], feature_dim_1, feature_dim_2, channel)
x_test_reshaped =  x_test.reshape(x_test.shape[0], feature_dim_1, feature_dim_2, channel)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, Activation, MaxPooling2D, Dropout, Flatten, Dense, BatchNormalization
from tensorflow.keras.layers import LeakyReLU

model = Sequential()

# Convolutional layer 1
model.add(Conv2D(32, (2, 2), input_shape=(feature_dim_1, feature_dim_2, channel), kernel_initializer='he_uniform'))
model.add(LeakyReLU(alpha=0.1))
model.add(BatchNormalization())

# Convolutional layer 2
model.add(Conv2D(32, (2, 2), kernel_initializer='he_uniform'))
model.add(LeakyReLU(alpha=0.1))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.6))

# Convolutional layer 3
model.add(Conv2D(32, (2, 2), kernel_initializer='he_uniform'))
model.add(LeakyReLU(alpha=0.1))

# Convolutional layer 4
model.add(Conv2D(64, (3, 3), kernel_initializer='he_uniform'))
model.add(LeakyReLU(alpha=0.1))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.5))

# Flattening
model.add(Flatten())

# Fully connected layer 1
model.add(Dense(64, kernel_initializer='he_uniform'))
model.add(LeakyReLU(alpha=0.1))
model.add(Dropout(0.5))

# Output layer
model.add(Dense(1, activation='sigmoid'))

# %%
callbacks = [TensorBoard(log_dir='./logs')]

# %%
import tensorflow as tf
from tensorflow import keras

# Assuming model is already defined and x_train_reshaped, y_train, x_val_reshaped, y_val, and callbacks are defined

model.compile(loss=keras.losses.binary_crossentropy,
              optimizer=tf.keras.optimizers.Adam(learning_rate=0.0005),
              metrics=['accuracy'])

history = model.fit(x_train_reshaped, y_train,
                    batch_size=64,
                    epochs=200,
                    verbose=1,
                    validation_data=(x_val_reshaped, y_val),
                    callbacks=callbacks,
                    class_weight={0: 1, 1: int(len(y_train)/y_train.sum())})
# Out:
# Epoch 1/200
# 14/14 [==============================] - 6s 245ms/step - loss: 54.5769 - accuracy: 0.6105 - val_loss: 4.5544 - val_accuracy: 0.7254
# Epoch 2/200
200
# 14/14 [==============================] - 2s 160ms/step - loss: 0.1969 - accuracy: 0.9532 - val_loss: 7.6059 - val_accuracy: 0.4134
# Epoch 75/200
# 14/14 [==============================] - 2s 161ms/step - loss: 0.1164 - accuracy: 0.9649 - val_loss: 10.0481 - val_accuracy: 0.3775
# Epoch 76/200
# 14/14 [==============================] - 2s 161ms/step - loss: 0.1552 - accuracy: 0.9661 - val_loss: 8.9771 - val_accuracy: 0.3869
# Epoch 77/200
# 14/14 [==============================] - 2s 162ms/step - loss: 0.1147 - accuracy: 0.9743 - val_loss: 8.5665 - val_accuracy: 0.3947
# Epoch 78/200
# 14/14 [==============================] - 2s 161ms/step - loss: 0.1056 - accuracy: 0.9743 - val_loss: 8.6088 - val_accuracy: 0.4212
# Epoch 79/200
# 14/14 [==============================] - 2s 160ms/step - loss: 0.0853 - accuracy: 0.9813 - val_loss: 9.1205 - val_accuracy: 0.3963
# Epoch 80/200
# 14/14 [==============================] - 2s 160ms/step - loss: 0.0847 - accuracy: 0.9754 - val_loss: 9.0233 - val_accuracy: 0.4025
# Epoch 81/200
# 14/14 [==============================] - 2s 161ms/step - loss: 0.1131 - accuracy: 0.9813 - val_loss: 6.6010 - val_accuracy: 0.4446
# Epoch 82/200
# 14/14 [==============================] - 2s 160ms/step - loss: 0.1223 - accuracy: 0.9626 - val_loss: 7.1483 - val_accuracy: 0.4446
# Epoch 83/200
# 14/14 [==============================] - 2s 160ms/step - loss: 0.0922 - accuracy: 0.9825 - val_loss: 10.8884 - val_accuracy: 0.3853
# Epoch 84/200
# 14/14 [==============================] - 2s 160ms/step - loss: 0.0672 - accuracy: 0.9836 - val_loss: 9.6443 - val_accuracy: 0.3931
# Epoch 85/200
# 14/14 [==============================] - 2s 161ms/step - loss: 0.0834 - accuracy: 0.9825 - val_loss: 10.5131 - val_accuracy: 0.3885
# Epoch 86/200
# 14/14 [==============================] - 2s 160ms/step - loss: 0.1041 - accuracy: 0.9731 - val_loss: 5.4616 - val_accuracy: 0.4883
# Epoch 87/200
# 14/14 [==============================] - 2s 161ms/step - loss: 0.1201 - accuracy: 0.9754 - val_loss: 8.2028 - val_accuracy: 0.4306
# Epoch 88/200
# 14/14 [==============================] - 2s 161ms/step - loss: 0.0810 - accuracy: 0.9836 - val_loss: 8.1424 - val_accuracy: 0.4150
# Epoch 89/200
# 14/14 [==============================] - 2s 161ms/step - loss: 0.1345 - accuracy: 0.9637 - val_loss: 7.6677 - val_accuracy: 0.4384
# Epoch 90/200
# 14/14 [==============================] - 2s 160ms/step - loss: 0.1022 - accuracy: 0.9778 - val_loss: 8.5683 - val_accuracy: 0.4197
# Epoch 91/200
# 14/14 [==============================] - 2s 160ms/step - loss: 0.0863 - accuracy: 0.9754 - val_loss: 11.7194 - val_accuracy: 0.3775
# Epoch 92/200
# 14/14 [==============================] - 2s 160ms/step - loss: 0.0757 - accuracy: 0.9871 - val_loss: 5.2144 - val_accuracy: 0.5179
# Epoch 93/200
# 14/14 [==============================] - 2s 160ms/step - loss: 0.1020 - accuracy: 0.9743 - val_loss: 7.1934 - val_accuracy: 0.4540
# Epoch 94/200
# 14/14 [==============================] - 2s 160ms/step - loss: 0.1045 - accuracy: 0.9789 - val_loss: 10.5069 - val_accuracy: 0.4103
# Epoch 95/200
# 14/14 [==============================] - 2s 160ms/step - loss: 0.0894 - accuracy: 0.9754 - val_loss: 10.6033 - val_accuracy: 0.4103
# Epoch 96/200
# 14/14 [==============================] - 2s 160ms/step - loss: 0.0704 - accuracy: 0.9766 - val_loss: 7.2840 - val_accuracy: 0.4571
# Epoch 97/200
# 14/14 [==============================] - 2s 160ms/step - loss: 0.0818 - accuracy: 0.9789 - val_loss: 7.7770 - val_accuracy: 0.4477
# Epoch 98/200
# 14/14 [==============================] - 2s 160ms/step - loss: 0.0468 - accuracy: 0.9895 - val_loss: 9.4474 - val_accuracy: 0.4181
# Epoch 99/200
# 14/14 [==============================] - 2s 160ms/step - loss: 0.0755 - accuracy: 0.9871 - val_loss: 8.4437 - val_accuracy: 0.4228
# Epoch 100/200
# 14/14 [==============================] - 2s 160ms/step - loss: 0.0879 - accuracy: 0.9789 - val_loss: 10.5344 - val_accuracy: 0.4087
# Epoch 101/200
# 14/14 [==============================] - 2s 160ms/step - loss: 0.0637 - accuracy: 0.9848 - val_loss: 7.7789 - val_accuracy: 0.4509
# Epoch 102/200
# 14/14 [==============================] - 2s 160ms/step - loss: 0.0930 - accuracy: 0.9731 - val_loss: 9.9747 - val_accuracy: 0.4212
# Epoch 103/200
# 14/14 [==============================] - 2s 160ms/step - loss: 0.0644 - accuracy: 0.9871 - val_loss: 6.2425 - val_accuracy: 0.5055
# Epoch 104/200
# 14/14 [==============================] - 2s 160ms/step - loss: 0.0889 - accuracy: 0.9743 - val_loss: 9.2237 - val_accuracy: 0.4446
# Epoch 105/200
# 14/14 [==============================] - 2s 161ms/step - loss: 0.0766 - accuracy: 0.9836 - val_loss: 7.1955 - val_accuracy: 0.5039
# Epoch 106/200
# 14/14 [==============================] - 2s 161ms/step - loss: 0.0823 - accuracy: 0.9778 - val_loss: 8.2873 - val_accuracy: 0.4618
# Epoch 107/200
# 14/14 [==============================] - 2s 161ms/step - loss: 0.0692 - accuracy: 0.9871 - val_loss: 7.8943 - val_accuracy: 0.4509
# Epoch 108/200
# 14/14 [==============================] - 2s 160ms/step - loss: 0.0629 - accuracy: 0.9825 - val_loss: 8.4761 - val_accuracy: 0.4509
# Epoch 109/200
# 14/14 [==============================] - 2s 159ms/step - loss: 0.0899 - accuracy: 0.9871 - val_loss: 9.5690 - val_accuracy: 0.4259
# Epoch 110/200
# 14/14 [==============================] - 2s 160ms/step - loss: 0.0679 - accuracy: 0.9825 - val_loss: 9.5708 - val_accuracy: 0.4197
# Epoch 111/200
# 14/14 [==============================] - 2s 160ms/step - loss: 0.0493 - accuracy: 0.9895 - val_loss: 10.8643 - val_accuracy: 0.3931
# Epoch 112/200
# 14/14 [==============================] - 2s 160ms/step - loss: 0.0329 - accuracy: 0.9918 - val_loss: 8.5106 - val_accuracy: 0.4462
# Epoch 113/200
# 14/14 [==============================] - 2s 161ms/step - loss: 0.0792 - accuracy: 0.9848 - val_loss: 7.1200 - val_accuracy: 0.4789
# Epoch 114/200
# 14/14 [==============================] - 2s 160ms/step - loss: 0.0921 - accuracy: 0.9836 - val_loss: 11.3648 - val_accuracy: 0.3978
# Epoch 115/200
# 14/14 [==============================] - 2s 160ms/step - loss: 0.0443 - accuracy: 0.9906 - val_loss: 7.5401 - val_accuracy: 0.4805
# Epoch 116/200
# 14/14 [==============================] - 2s 160ms/step - loss: 0.0306 - accuracy: 0.9918 - val_loss: 8.3987 - val_accuracy: 0.4633
# Epoch 117/200
# 14/14 [==============================] - 2s 160ms/step - loss: 0.0351 - accuracy: 0.9895 - val_loss: 8.1001 - val_accuracy: 0.4680
# Epoch 118/200
# 14/14 [==============================] - 2s 161ms/step - loss: 0.0376 - accuracy: 0.9883 - val_loss: 5.9729 - val_accuracy: 0.5320
# Epoch 119/200
# 14/14 [==============================] - 2s 160ms/step - loss: 0.0462 - accuracy: 0.9906 - val_loss: 5.5721 - val_accuracy: 0.5413
# Epoch 120/200
# 14/14 [==============================] - 2s 160ms/step - loss: 0.0446 - accuracy: 0.9906 - val_loss: 6.6788 - val_accuracy: 0.4977
# Epoch 121/200
# 14/14 [==============================] - 2s 161ms/step - loss: 0.0437 - accuracy: 0.9860 - val_loss: 5.3289 - val_accuracy: 0.5460
# Epoch 122/200
# 14/14 [==============================] - 2s 160ms/step - loss: 0.1004 - accuracy: 0.9906 - val_loss: 10.7279 - val_accuracy: 0.4041
# Epoch 123/200
# 14/14 [==============================] - 2s 160ms/step - loss: 0.0818 - accuracy: 0.9801 - val_loss: 6.4365 - val_accuracy: 0.5070
# Epoch 124/200
# 14/14 [==============================] - 2s 160ms/step - loss: 0.0628 - accuracy: 0.9836 - val_loss: 7.2452 - val_accuracy: 0.4945
# Epoch 125/200
# 14/14 [==============================] - 2s 160ms/step - loss: 0.0851 - accuracy: 0.9883 - val_loss: 5.0430 - val_accuracy: 0.5741
# Epoch 126/200
# 14/14 [==============================] - 2s 160ms/step - loss: 0.0898 - accuracy: 0.9661 - val_loss: 3.5443 - val_accuracy: 0.6147
# Epoch 127/200
# 14/14 [==============================] - 2s 160ms/step - loss: 0.0585 - accuracy: 0.9906 - val_loss: 6.6188 - val_accuracy: 0.5117
# Epoch 128/200
# 14/14 [==============================] - 2s 161ms/step - loss: 0.0525 - accuracy: 0.9871 - val_loss: 5.8854 - val_accuracy: 0.5398
# Epoch 129/200
# 14/14 [==============================] - 2s 160ms/step - loss: 0.0636 - accuracy: 0.9801 - val_loss: 5.0956 - val_accuracy: 0.5803
# Epoch 130/200
# 14/14 [==============================] - 2s 160ms/step - loss: 0.0612 - accuracy: 0.9860 - val_loss: 6.1062 - val_accuracy: 0.5320
# Epoch 131/200
# 14/14 [==============================] - 2s 160ms/step - loss: 0.0567 - accuracy: 0.9860 - val_loss: 7.2259 - val_accuracy: 0.5008
# Epoch 132/200
# 14/14 [==============================] - 2s 161ms/step - loss: 0.0256 - accuracy: 0.9918 - val_loss: 8.0175 - val_accuracy: 0.4914
# Epoch 133/200
# 14/14 [==============================] - 2s 160ms/step - loss: 0.0390 - accuracy: 0.9918 - val_loss: 7.0009 - val_accuracy: 0.5023
# Epoch 134/200
# 14/14 [==============================] - 2s 161ms/step - loss: 0.0247 - accuracy: 0.9965 - val_loss: 7.4894 - val_accuracy: 0.4992
# Epoch 135/200
# 14/14 [==============================] - 2s 160ms/step - loss: 0.0256 - accuracy: 0.9918 - val_loss: 8.6686 - val_accuracy: 0.4540
# Epoch 136/200
# 14/14 [==============================] - 2s 161ms/step - loss: 0.0385 - accuracy: 0.9930 - val_loss: 5.4575 - val_accuracy: 0.5725
# Epoch 137/200
# 14/14 [==============================] - 2s 159ms/step - loss: 0.0398 - accuracy: 0.9953 - val_loss: 6.6660 - val_accuracy: 0.4961
# Epoch 138/200
# 14/14 [==============================] - 2s 160ms/step - loss: 0.0507 - accuracy: 0.9942 - val_loss: 7.2277 - val_accuracy: 0.4977
# Epoch 139/200
# 14/14 [==============================] - 2s 161ms/step - loss: 0.0267 - accuracy: 0.9918 - val_loss: 7.3419 - val_accuracy: 0.5055
# Epoch 140/200
# 14/14 [==============================] - 2s 160ms/step - loss: 0.0277 - accuracy: 0.9930 - val_loss: 7.5703 - val_accuracy: 0.4992
# Epoch 141/200
# 14/14 [==============================] - 2s 160ms/step - loss: 0.0356 - accuracy: 0.9906 - val_loss: 7.5137 - val_accuracy: 0.4852
# Epoch 142/200
# 14/14 [==============================] - 2s 161ms/step - loss: 0.0464 - accuracy: 0.9883 - val_loss: 5.2241 - val_accuracy: 0.5741
# Epoch 143/200
# 14/14 [==============================] - 2s 160ms/step - loss: 0.0291 - accuracy: 0.9930 - val_loss: 5.3915 - val_accuracy: 0.5772
# Epoch 144/200
# 14/14 [==============================] - 2s 161ms/step - loss: 0.0356 - accuracy: 0.9930 - val_loss: 5.2328 - val_accuracy: 0.5663
# Epoch 145/200
# 14/14 [==============================] - 2s 160ms/step - loss: 0.0380 - accuracy: 0.9918 - val_loss: 5.3439 - val_accuracy: 0.5850
# Epoch 146/200
# 14/14 [==============================] - 2s 160ms/step - loss: 0.0448 - accuracy: 0.9918 - val_loss: 6.6291 - val_accuracy: 0.5335
# Epoch 147/200
# 14/14 [==============================] - 2s 161ms/step - loss: 0.0377 - accuracy: 0.9836 - val_loss: 6.3386 - val_accuracy: 0.5632
# Epoch 148/200
# 14/14 [==============================] - 2s 160ms/step - loss: 0.0300 - accuracy: 0.9942 - val_loss: 5.5765 - val_accuracy: 0.5866
# Epoch 149/200
# 14/14 [==============================] - 2s 160ms/step - loss: 0.0633 - accuracy: 0.9848 - val_loss: 4.7770 - val_accuracy: 0.5991
# Epoch 150/200
# 14/14 [==============================] - 2s 160ms/step - loss: 0.0556 - accuracy: 0.9883 - val_loss: 3.2204 - val_accuracy: 0.6786
# Epoch 151/200
# 14/14 [==============================] - 2s 160ms/step - loss: 0.0396 - accuracy: 0.9871 - val_loss: 5.7112 - val_accuracy: 0.5788
# Epoch 152/200
# 14/14 [==============================] - 2s 160ms/step - loss: 0.0353 - accuracy: 0.9895 - val_loss: 5.0228 - val_accuracy: 0.6100
# Epoch 153/200
# 14/14 [==============================] - 2s 161ms/step - loss: 0.0166 - accuracy: 0.9953 - val_loss: 5.0621 - val_accuracy: 0.6100
# Epoch 154/200
# 14/14 [==============================] - 2s 161ms/step - loss: 0.0492 - accuracy: 0.9918 - val_loss: 6.0457 - val_accuracy: 0.5616
# Epoch 155/200
# 14/14 [==============================] - 2s 159ms/step - loss: 0.0605 - accuracy: 0.9906 - val_loss: 5.6297 - val_accuracy: 0.5757
# Epoch 156/200
# 14/14 [==============================] - 2s 160ms/step - loss: 0.0390 - accuracy: 0.9930 - val_loss: 6.2684 - val_accuracy: 0.5585
# Epoch 157/200
# 14/14 [==============================] - 2s 160ms/step - loss: 0.0810 - accuracy: 0.9848 - val_loss: 5.6929 - val_accuracy: 0.5741
# Epoch 158/200
# 14/14 [==============================] - 2s 161ms/step - loss: 0.0536 - accuracy: 0.9860 - val_loss: 11.1782 - val_accuracy: 0.4555
# Epoch 159/200
# 14/14 [==============================] - 2s 161ms/step - loss: 0.0742 - accuracy: 0.9918 - val_loss: 4.1157 - val_accuracy: 0.6396
# Epoch 160/200
# 14/14 [==============================] - 2s 160ms/step - loss: 0.0965 - accuracy: 0.9731 - val_loss: 4.5698 - val_accuracy: 0.5913
# Epoch 161/200
# 14/14 [==============================] - 2s 161ms/step - loss: 0.0772 - accuracy: 0.9918 - val_loss: 6.6263 - val_accuracy: 0.5382
# Epoch 162/200
# 14/14 [==============================] - 2s 162ms/step - loss: 0.0280 - accuracy: 0.9942 - val_loss: 6.3177 - val_accuracy: 0.5491
# Epoch 163/200
# 14/14 [==============================] - 2s 161ms/step - loss: 0.0245 - accuracy: 0.9953 - val_loss: 5.7131 - val_accuracy: 0.5663
# Epoch 164/200
# 14/14 [==============================] - 2s 161ms/step - loss: 0.0294 - accuracy: 0.9930 - val_loss: 5.1637 - val_accuracy: 0.5819
# Epoch 165/200
# 14/14 [==============================] - 2s 161ms/step - loss: 0.0320 - accuracy: 0.9906 - val_loss: 6.1108 - val_accuracy: 0.5663
# Epoch 166/200
# 14/14 [==============================] - 2s 162ms/step - loss: 0.0345 - accuracy: 0.9930 - val_loss: 4.8459 - val_accuracy: 0.5975
# Epoch 167/200
# 14/14 [==============================] - 2s 160ms/step - loss: 0.0312 - accuracy: 0.9930 - val_loss: 5.8028 - val_accuracy: 0.5788
# Epoch 168/200
# 14/14 [==============================] - 2s 160ms/step - loss: 0.0195 - accuracy: 0.9942 - val_loss: 5.7227 - val_accuracy: 0.5850
# Epoch 169/200
# 14/14 [==============================] - 2s 160ms/step - loss: 0.0147 - accuracy: 0.9953 - val_loss: 6.2475 - val_accuracy: 0.5757
# Epoch 170/200
# 14/14 [==============================] - 2s 160ms/step - loss: 0.0315 - accuracy: 0.9942 - val_loss: 4.9206 - val_accuracy: 0.6225
# Epoch 171/200
# 14/14 [==============================] - 2s 161ms/step - loss: 0.0336 - accuracy: 0.9906 - val_loss: 6.2460 - val_accuracy: 0.5725
# Epoch 172/200
# 14/14 [==============================] - 2s 160ms/step - loss: 0.0499 - accuracy: 0.9895 - val_loss: 8.2725 - val_accuracy: 0.4977
# Epoch 173/200
# 14/14 [==============================] - 2s 160ms/step - loss: 0.1048 - accuracy: 0.9871 - val_loss: 6.5871 - val_accuracy: 0.5335
# Epoch 174/200
# 14/14 [==============================] - 2s 160ms/step - loss: 0.0359 - accuracy: 0.9871 - val_loss: 4.8017 - val_accuracy: 0.5928
# Epoch 175/200
# 14/14 [==============================] - 2s 160ms/step - loss: 0.0476 - accuracy: 0.9906 - val_loss: 5.0987 - val_accuracy: 0.6100
# Epoch 176/200
# 14/14 [==============================] - 2s 161ms/step - loss: 0.0631 - accuracy: 0.9895 - val_loss: 4.9654 - val_accuracy: 0.6037
# Epoch 177/200
# 14/14 [==============================] - 2s 161ms/step - loss: 0.0630 - accuracy: 0.9906 - val_loss: 7.3687 - val_accuracy: 0.5133
# Epoch 178/200
# 14/14 [==============================] - 2s 161ms/step - loss: 0.0478 - accuracy: 0.9930 - val_loss: 5.1816 - val_accuracy: 0.6037
# Epoch 179/200
# 14/14 [==============================] - 2s 160ms/step - loss: 0.0471 - accuracy: 0.9871 - val_loss: 8.1388 - val_accuracy: 0.5086
# Epoch 180/200
# 14/14 [==============================] - 2s 160ms/step - loss: 0.0293 - accuracy: 0.9918 - val_loss: 4.6519 - val_accuracy: 0.6240
# Epoch 181/200
# 14/14 [==============================] - 2s 160ms/step - loss: 0.0363 - accuracy: 0.9918 - val_loss: 4.9654 - val_accuracy: 0.6318
# Epoch 182/200
# 14/14 [==============================] - 2s 160ms/step - loss: 0.0757 - accuracy: 0.9871 - val_loss: 7.0578 - val_accuracy: 0.5507
# Epoch 183/200
# 14/14 [==============================] - 2s 160ms/step - loss: 0.0312 - accuracy: 0.9906 - val_loss: 6.4436 - val_accuracy: 0.5616
# Epoch 184/200
# 14/14 [==============================] - 2s 160ms/step - loss: 0.0446 - accuracy: 0.9942 - val_loss: 5.2630 - val_accuracy: 0.6115
# Epoch 185/200
# 14/14 [==============================] - 2s 160ms/step - loss: 0.0255 - accuracy: 0.9918 - val_loss: 4.8112 - val_accuracy: 0.6225
# Epoch 186/200
# 14/14 [==============================] - 2s 160ms/step - loss: 0.0247 - accuracy: 0.9965 - val_loss: 5.4399 - val_accuracy: 0.5741
# Epoch 187/200
# 14/14 [==============================] - 2s 162ms/step - loss: 0.0552 - accuracy: 0.9813 - val_loss: 5.7410 - val_accuracy: 0.5928
# Epoch 188/200
# 14/14 [==============================] - 2s 161ms/step - loss: 0.0333 - accuracy: 0.9906 - val_loss: 6.4598 - val_accuracy: 0.5569
# Epoch 189/200
# 14/14 [==============================] - 2s 161ms/step - loss: 0.0189 - accuracy: 0.9942 - val_loss: 5.4668 - val_accuracy: 0.6006
# Epoch 190/200
# 14/14 [==============================] - 2s 160ms/step - loss: 0.0480 - accuracy: 0.9918 - val_loss: 7.8424 - val_accuracy: 0.5242
# Epoch 191/200
# 14/14 [==============================] - 2s 160ms/step - loss: 0.0373 - accuracy: 0.9918 - val_loss: 6.3573 - val_accuracy: 0.5554
# Epoch 192/200
# 14/14 [==============================] - 2s 161ms/step - loss: 0.0325 - accuracy: 0.9906 - val_loss: 8.1035 - val_accuracy: 0.5211
# Epoch 193/200
# 14/14 [==============================] - 2s 161ms/step - loss: 0.0259 - accuracy: 0.9942 - val_loss: 6.7737 - val_accuracy: 0.5616
# Epoch 194/200
# 14/14 [==============================] - 2s 161ms/step - loss: 0.0229 - accuracy: 0.9930 - val_loss: 4.3352 - val_accuracy: 0.6505
# Epoch 195/200
# 14/14 [==============================] - 2s 161ms/step - loss: 0.0272 - accuracy: 0.9930 - val_loss: 7.1764 - val_accuracy: 0.5601
# Epoch 196/200
# 14/14 [==============================] - 2s 160ms/step - loss: 0.0394 - accuracy: 0.9930 - val_loss: 6.1152 - val_accuracy: 0.5710
# Epoch 197/200
# 14/14 [==============================] - 2s 160ms/step - loss: 0.0818 - accuracy: 0.9778 - val_loss: 3.8772 - val_accuracy: 0.6115
# Epoch 198/200
# 14/14 [==============================] - 2s 161ms/step - loss: 0.0695 - accuracy: 0.9895 - val_loss: 6.1803 - val_accuracy: 0.5585
# Epoch 199/200
# 14/14 [==============================] - 2s 160ms/step - loss: 0.0456 - accuracy: 0.9848 - val_loss: 4.0826 - val_accuracy: 0.7083
# Epoch 200/200
# 14/14 [==============================] - 2s 160ms/step - loss: 0.0414 - accuracy: 0.9930 - val_loss: 3.4561 - val_accuracy: 0.7098

# %%
train_loss = history.history['loss'][5:]
val_loss = history.history['val_loss'][5:]
train_acc = history.history['accuracy'][5:]
val_acc = history.history['val_accuracy'][5:]

epoch_count = range(1,len(train_acc)+1)

plt.subplots(1,2)
plt.subplot(1,2,1)
plt.plot(epoch_count, train_loss, 'r--')
plt.plot(epoch_count, val_acc,'b-')
plt.legend(['Training Loss','val_loss'])
plt.xlabel('Epoch')
plt.ylabel('loss')

plt.subplot(1,2,2)
plt.plot(epoch_count, train_acc,'r--')
plt.plot(epoch_count, val_acc, 'b-')
plt.legend(['Training Accuracy', 'Validation Accuracy'])
plt.xlabel('Epoch')
plt.ylabel('Accuracy')

plt.tight_layout()
plt.show()

# %%
print("Evaluate on test data")
results = model.evaluate(x_test_reshaped, y_test, batch_size = 128)
print("test loss, test acc:", results)
predictions = model.predict(x_test_reshaped)
print('predoctions shape: ', predictions.shape)
# Out:
# Evaluate on test data
# 6/6 [==============================] - 2s 76ms/step - loss: 3.7968 - accuracy: 0.6994
# test loss, test acc: [3.796816110610962, 0.6993769407272339]
# 21/21 [==============================] - 1s 16ms/step
# predoctions shape:  (642, 1)

# %%
from sklearn import metrics
fpr, tpr, thresholds = metrics.roc_curve(y_test, predictions)

# %%
ns_probs = [0 for _ in range(len(y_test))]
ns_fpr, ns_tpr, _ = metrics.roc_curve(y_test, ns_probs)

# %%
plt.plot(fpr, tpr, linestyle = '--', label = 'roc_auc_curve')
plt.plot(ns_fpr, ns_tpr, linestyle = '--', label = 'No Skill')

plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')

plt.legend()

plt.title('ROC AUC Curve')
plt.show()

# %%
from sklearn.metrics import confusion_matrix
cf_matrix = confusion_matrix(y_test, predictions.round())
print(confusion_matrix(y_test, predictions.round()))
# Out:
# [[375  96]
#  [ 97  74]]

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

if 'y_test' in locals() and 'predictions' in locals():
    cm = confusion_matrix(y_test, predictions.round())
    plt.figure(figsize=(6, 6))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['Pred 0', 'Pred 1'], yticklabels=['True 0', 'True 1'])
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.title('Confusion Matrix')
    plt.show()
else:
    print("Test labels or predictions not available.")

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, predictions.round()))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.79      0.80      0.80       471
#            1       0.44      0.43      0.43       171
#
#     accuracy                           0.70       642
#    macro avg       0.61      0.61      0.61       642
# weighted avg       0.70      0.70      0.70       642

# %%
model.save('200newmodel.h5')
print(model.summary())
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_12 (Conv2D)          (None, 19, 4588, 32)      160
#
#  leaky_re_lu (LeakyReLU)     (None, 19, 4588, 32)      0
#
#  batch_normalization (Batch  (None, 19, 4588, 32)      128
#  Normalization)
#
#  conv2d_13 (Conv2D)          (None, 18, 4587, 32)      4128
#
#  leaky_re_lu_1 (LeakyReLU)   (None, 18, 4587, 32)      0
#
#  max_pooling2d_6 (MaxPoolin  (None, 9, 2293, 32)       0
#  g2D)
#
#  dropout_9 (Dropout)         (None, 9, 2293, 32)       0
#
#  conv2d_14 (Conv2D)          (None, 8, 2292, 32)       4128
#
#  leaky_re_lu_2 (LeakyReLU)   (None, 8, 2292, 32)       0
#
#  conv2d_15 (Conv2D)          (None, 6, 2290, 64)       18496
#
#  leaky_re_lu_3 (LeakyReLU)   (None, 6, 2290, 64)       0
#
#  max_pooling2d_7 (MaxPoolin  (None, 3, 1145, 64)       0
#  g2D)
#
#  dropout_10 (Dropout)        (None, 3, 1145, 64)       0
#
#  flatten_3 (Flatten)         (None, 219840)            0
#
#  dense_6 (Dense)             (None, 64)                14069824
#
#  leaky_re_lu_4 (LeakyReLU)   (None, 64)                0
#
#  dropout_11 (Dropout)        (None, 64)                0
#
#  dense_7 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 14096929 (53.78 MB)
# Trainable params: 14096865 (53.78 MB)
# Non-trainable params: 64 (256.00 Byte)
# _________________________________________________________________
# None

# %%
model.save_weights('200newmodel_weights.h5')
